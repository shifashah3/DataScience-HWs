# %% [markdown]
# ## HW 1 - Data Cleaning and Wrangling
# ### Shifa Shah
# ### ss08336@st.habib.edu.pk

# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
df = pd.read_csv('580SurveyCleanup2.csv')

# %%
df.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0        No.             Time     Status  Duration (Seconds)  Access Code
# 1          1  10/3/2023 17:49  Completed               11646          NaN
# 2          2  10/3/2023 17:49  Completed                 113          NaN
# 3          3  10/3/2023 17:49  Completed                 572          NaN
# 4          4  10/3/2023 17:50  Completed                 365          NaN
#
#       Unnamed: 5      Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 0  Email Address      IP Address        Country     Region
# 1            NaN  100.36.167.226  United States   Virginia
# 2            NaN   98.169.26.134  United States   Virginia
# 3            NaN    98.169.52.23  United States   Virginia
# 4            NaN  69.255.182.253  United States   Virginia
#
#                Unnamed: 9  ...             Q12.1         Q12.2  \
# 0  City / Town / District  ...  Some familiarity  Average user
# ...

# %% [markdown]
# Separating columns of students profile information

# %%
df_1 = df.iloc[:,1:12]

# %%
df_1.head()
# Out:
#         Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4     Unnamed: 5  \
# 0             Time     Status  Duration (Seconds)  Access Code  Email Address
# 1  10/3/2023 17:49  Completed               11646          NaN            NaN
# 2  10/3/2023 17:49  Completed                 113          NaN            NaN
# 3  10/3/2023 17:49  Completed                 572          NaN            NaN
# 4  10/3/2023 17:50  Completed                 365          NaN            NaN
#
#        Unnamed: 6     Unnamed: 7 Unnamed: 8              Unnamed: 9  \
# 0      IP Address        Country     Region  City / Town / District
# 1  100.36.167.226  United States   Virginia                 Fairfax
# 2   98.169.26.134  United States   Virginia                 Fairfax
# 3    98.169.52.23  United States   Virginia          Greenway Downs
# 4  69.255.182.253  United States   Virginia             Gainesville
#
#   Unnamed: 10 Unnamed: 11
# 0    Latitude   Longitude
# 1    -77.2891     38.8209
# ...

# %% [markdown]
# ### Replacing header with first row

# %%
df_1.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
df_1.columns = df_1.iloc[0] # make the first row the new xolumn headers
df_1 = df_1[1:] # delete the first row

# %%
df_1.head()
# Out:
# 0             Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
# 0      IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# 0 Longitude
# 1   38.8209
# 2   38.8605
# 3   38.9645
# ...

# %% [markdown]
# ### Getting Question 1 coulumns

# %%
df2 = df.iloc[:,[12,13]]

# %%
df2.head()
# Out:
#     Q1  Q1.1
# 0  2.0   4.0
# 1  NaN   1.0
# 2  1.0   NaN
# 3  1.0   NaN
# 4  1.0   NaN

# %% [markdown]
# ### Replacing header with first row

# %%
df2.columns = df2.iloc[0].astype(str)
df2 = df2[1:]

# %%
df2.head()
# Out:
# 0  2.0  4.0
# 1  NaN  1.0
# 2  1.0  NaN
# 3  1.0  NaN
# 4  1.0  NaN
# 5  1.0  NaN

# %% [markdown]
# ### Replace every "1" value with its respective column name

# %%
df3 = df2.loc[:, '2.0':'4.0'].replace(1, pd.Series(df2.columns, df2.columns)).fillna('')

# %%
df3
# Out:
# 0   2.0  4.0
# 1        4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10       4.0
# 11  2.0
# 12       4.0
# 13  2.0
# 14  2.0
# 15       4.0
# 16       4.0
# 17  2.0
# 18  2.0
# 19       4.0
# 20       4.0
# 21       4.0
# 22  2.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26  2.0
# 27  2.0
# 28       4.0
# 29       4.0
# 30  2.0
# 31       4.0
# 32  2.0
# 33  2.0
# 34       4.0
# 35  2.0
# 36       4.0

# %% [markdown]
# ### concatenate Q1 columns into one final column

# %%
df4 = pd.DataFrame(df3.iloc[:,0] + df3.iloc[:,1])

# %%
df4
# Out:
#       0
# 1   4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10  4.0
# 11  2.0
# 12  4.0
# 13  2.0
# 14  2.0
# 15  4.0
# 16  4.0
# 17  2.0
# 18  2.0
# 19  4.0
# 20  4.0
# 21  4.0
# 22  2.0
# 23  4.0
# 24  4.0
# 25  4.0
# 26  2.0
# 27  2.0
# 28  4.0
# 29  4.0
# 30  2.0
# 31  4.0
# 32  2.0
# 33  2.0
# 34  4.0
# 35  2.0
# 36  4.0

# %%
df4.columns = ['Q1']

# %%
df4.head()
# Out:
#     Q1
# 1  4.0
# 2  2.0
# 3  2.0
# 4  2.0
# 5  2.0

# %%
df5 = pd.concat([df_1,df4],axis=1)

# %%
df5.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1
# 1   38.8209  4.0
# 2   38.8605  2.0
# ...

# %%
df5
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ## Formatting question 2

# %%
df6 = df.iloc[:,[14,15,16,17]]

# %%
df6
# Out:
#       Q2    Q2.1       Q2.2                  Q2.3
# 0   Male  Female  NonBinary  Prefer not to answer
# 1    NaN       1        NaN                   NaN
# 2    NaN       1        NaN                   NaN
# 3      1     NaN        NaN                   NaN
# 4    NaN     NaN        NaN                     1
# 5      1     NaN        NaN                   NaN
# 6    NaN       1        NaN                   NaN
# 7    NaN     NaN          1                   NaN
# 8    NaN       1        NaN                   NaN
# 9      1     NaN        NaN                   NaN
# 10     1     NaN        NaN                   NaN
# 11   NaN       1        NaN                   NaN
# 12   NaN       1        NaN                   NaN
# 13     1     NaN        NaN                   NaN
# 14   NaN       1        NaN                   NaN
# 15   NaN       1        NaN                   NaN
# 16     1     NaN        NaN                   NaN
# 17     1     NaN        NaN                   NaN
# ...

# %% [markdown]
# ### Replacing header with first row

# %%
df6.columns = df6.iloc[0].astype(str)
df6 = df6[1:]

# %%
df6
# Out:
# 0  Male Female NonBinary Prefer not to answer
# 1   NaN      1       NaN                  NaN
# 2   NaN      1       NaN                  NaN
# 3     1    NaN       NaN                  NaN
# 4   NaN    NaN       NaN                    1
# 5     1    NaN       NaN                  NaN
# 6   NaN      1       NaN                  NaN
# 7   NaN    NaN         1                  NaN
# 8   NaN      1       NaN                  NaN
# 9     1    NaN       NaN                  NaN
# 10    1    NaN       NaN                  NaN
# 11  NaN      1       NaN                  NaN
# 12  NaN      1       NaN                  NaN
# 13    1    NaN       NaN                  NaN
# 14  NaN      1       NaN                  NaN
# 15  NaN      1       NaN                  NaN
# 16    1    NaN       NaN                  NaN
# 17    1    NaN       NaN                  NaN
# 18    1    NaN       NaN                  NaN
# 19    1    NaN       NaN                  NaN
# ...

# %% [markdown]
# ### Replace every "1" value with its respective column name

# %%
for col in ['Male', 'Female', 'NonBinary', 'Prefer not to answer']:
    df6.loc[df6[col] == "1", col] = col
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6608\1324660356.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6.loc[df6[col] == "1", col] = col

# %%
df6
# Out:
# 0   Male  Female  NonBinary  Prefer not to answer
# 1    NaN  Female        NaN                   NaN
# 2    NaN  Female        NaN                   NaN
# 3   Male     NaN        NaN                   NaN
# 4    NaN     NaN        NaN  Prefer not to answer
# 5   Male     NaN        NaN                   NaN
# 6    NaN  Female        NaN                   NaN
# 7    NaN     NaN  NonBinary                   NaN
# 8    NaN  Female        NaN                   NaN
# 9   Male     NaN        NaN                   NaN
# 10  Male     NaN        NaN                   NaN
# 11   NaN  Female        NaN                   NaN
# 12   NaN  Female        NaN                   NaN
# 13  Male     NaN        NaN                   NaN
# 14   NaN  Female        NaN                   NaN
# 15   NaN  Female        NaN                   NaN
# 16  Male     NaN        NaN                   NaN
# 17  Male     NaN        NaN                   NaN
# 18  Male     NaN        NaN                   NaN
# ...

# %%
df6 = df6.fillna('') # replacing NaN with empty string

# %% [markdown]
# ### Concatenate all the columns into one single column

# %%
df6 = pd.DataFrame(df6.iloc[:,0] + df6.iloc[:,1] + df6.iloc[:,2] + df6.iloc[:,3])

# %%
df6
# Out:
#                        0
# 1                 Female
# 2                 Female
# 3                   Male
# 4   Prefer not to answer
# 5                   Male
# 6                 Female
# 7              NonBinary
# 8                 Female
# 9                   Male
# 10                  Male
# 11                Female
# 12                Female
# 13                  Male
# 14                Female
# 15                Female
# 16                  Male
# 17                  Male
# 18                  Male
# 19                  Male
# 20                Female
# 21                  Male
# 22                Female
# 23                Female
# 24                  Male
# 25                Female
# 26                  Male
# 27                  Male
# 28                  Male
# 29                Female
# 30                  Male
# 31                Female
# 32                Female
# 33                  Male
# 34                  Male
# 35                  Male
# 36                Female

# %% [markdown]
# ### Replace the header with the question number

# %%
df6.columns = ['Q2']
df6.head()
# Out:
#                      Q2
# 1                Female
# 2                Female
# 3                  Male
# 4  Prefer not to answer
# 5                  Male

# %%
df7 = pd.concat([df5,df6],axis=1)
df7.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1                    Q2
# ...

# %% [markdown]
# ### Formating question 3

# %%
df8 = df.iloc[:,[18]]
df8
# Out:
#              Q3
# 0   Age (years)
# 1            23
# 2            24
# 3            40
# 4            26
# 5            30
# 6            25
# 7            24
# 8            30
# 9            24
# 10           26
# 11           24
# 12           25
# 13           25
# 14           23
# 15           31
# 16           26
# 17           40
# 18          2 3
# 19           25
# 20           22
# 21           23
# 22           25
# 23           22
# 24           23
# 25           27
# 26           28
# 27           23
# 28           35
# 29           27
# 30           25
# 31           55
# 32           23
# 33         1993
# 34           23
# 35           24
# 36           28

# %%
df8 = df8[1:]
df8
# Out:
#       Q3
# 1     23
# 2     24
# 3     40
# 4     26
# 5     30
# 6     25
# 7     24
# 8     30
# 9     24
# 10    26
# 11    24
# 12    25
# 13    25
# 14    23
# 15    31
# 16    26
# 17    40
# 18   2 3
# 19    25
# 20    22
# 21    23
# 22    25
# 23    22
# 24    23
# 25    27
# 26    28
# 27    23
# 28    35
# 29    27
# 30    25
# 31    55
# 32    23
# 33  1993
# 34    23
# 35    24
# 36    28

# %%
df9 = pd.concat([df7,df8],axis=1)
df9.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1                    Q2  Q3
# ...

# %% [markdown]
# ### Formatting Question 4

# %%
df10 = df.iloc[:,[19]]
df10.head()
# Out:
#                 Q4
# 0  Height (Inches)
# 1               63
# 2               59
# 3               70
# 4               66

# %%
df10 = df10.loc[1:]
df10.head()
# Out:
#    Q4
# 1  63
# 2  59
# 3  70
# 4  66
# 5  70

# %%
df11 = pd.concat([df9,df10],axis=1)
df11.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1                    Q2  Q3  Q4
# ...

# %% [markdown]
# ### Formatting question 5

# %%
df12 = df.iloc[:,[20]]
df12.head()
# Out:
#                        Q5
# 0  Country of Citizenship
# 1                  Taiwan
# 2                   India
# 3                   India
# 4             South Korea

# %%
df12 = df12.loc[1:]
df12.head()
# Out:
#             Q5
# 1       Taiwan
# 2        India
# 3        India
# 4  South Korea
# 5           US

# %%
df13 = pd.concat([df11,df12],axis=1)
df13.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# ...

# %% [markdown]
# ### Formatting Question 6

# %%
df14 = df.iloc[:,[21]]
df14.head()
# Out:
#                       Q6
# 0   Undergraduate Degree
# 1              economics
# 2               Finance
# 3  Computer Applications
# 4    Business Management

# %%
df14 = df14.loc[1:]
df14
# Out:
#                           Q6
# 1                  economics
# 2                   Finance
# 3      Computer Applications
# 4        Business Management
# 5                        Yes
# 6                        NaN
# 7                    Finance
# 8                        NaN
# 9                   Economic
# 10   Economics with Finance
# 11                       BIT
# 12      Computer Engineering
# 13                   Biology
# 14                       Cse
# 15                Management
# 16    Economics with Finance
# 17                 Economics
# 18              Engineering
# 19       Accounting and ISOM
# 20                Statistics
# 21         Computer Science
# 22         Computer science
# 23  Mathematics & Statistics
# 24                 Economics
# 25       Systems Engineering
# 26         Civil engineering
# 27                       ECE
# 28        Quantity Surveying
# 29   Bachelor of Engineering
# 30              B.Tech in CS
# 31             BS accounting
# ...

# %%
df15 = pd.concat([df13,df14],axis=1)
df15.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# ...

# %% [markdown]
# ### Formatting Question 7

# %%
df16 = df.iloc[:,22]
df16.head()
# Out:
# 0    Expected Graduation date from Mason MS program?
# 1                                         12/31/2021
# 2                                           5/1/2021
# 3                                           6/1/2022
# 4                                         12/31/2021
# Name: Q7, dtype: object

# %%
df16 = df16.loc[1:]
df16.head()
# Out:
# 1    12/31/2021
# 2      5/1/2021
# 3      6/1/2022
# 4    12/31/2021
# 5      1/1/2021
# Name: Q7, dtype: object

# %%
df17 = pd.concat([df15,df16],axis=1)
df17.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# ...

# %% [markdown]
# ### Formatting Question 8

# %%
df18 = df.iloc[:,[23,24,25,26]]
df18
# Out:
#                    Q8           Q8.1   Q8.2          Q8.3
# 0   Microsoft/Windows  Apple/MacBook  Other           NaN
# 1                 NaN              1    NaN           NaN
# 2                 NaN              1    NaN           NaN
# 3                 NaN              1    NaN           NaN
# 4                   1            NaN    NaN           NaN
# 5                 NaN              2    NaN           NaN
# 6                 NaN            NaN    NaN           NaN
# 7                   1            NaN    NaN           NaN
# 8                 NaN            NaN    NaN           NaN
# 9                   1            NaN    NaN           NaN
# 10                NaN            NaN    NaN           NaN
# 11                  1            NaN    NaN           NaN
# 12                  1            NaN    NaN           NaN
# 13                NaN              1    NaN           NaN
# 14                  1            NaN    NaN           NaN
# ...

# %%
df18.columns = df18.iloc[0].astype(str)
df18 = df18[1:]

# %%
df18
# Out:
# 0  Microsoft/Windows Apple/MacBook Other           nan
# 1                NaN             1   NaN           NaN
# 2                NaN             1   NaN           NaN
# 3                NaN             1   NaN           NaN
# 4                  1           NaN   NaN           NaN
# 5                NaN             2   NaN           NaN
# 6                NaN           NaN   NaN           NaN
# 7                  1           NaN   NaN           NaN
# 8                NaN           NaN   NaN           NaN
# 9                  1           NaN   NaN           NaN
# 10               NaN           NaN   NaN           NaN
# 11                 1           NaN   NaN           NaN
# 12                 1           NaN   NaN           NaN
# 13               NaN             1   NaN           NaN
# 14                 1           NaN   NaN           NaN
# 15                 1           NaN   NaN           NaN
# 16                 1           NaN   NaN           NaN
# ...

# %%
df18 = df18.fillna('') # replacing NaN with empty string
df18
# Out:
# 0  Microsoft/Windows Apple/MacBook Other           nan
# 1                                1
# 2                                1
# 3                                1
# 4                  1
# 5                                2
# 6
# 7                  1
# 8
# 9                  1
# 10
# 11                 1
# 12                 1
# 13                               1
# 14                 1
# 15                 1
# 16                 1
# 17                 1             1
# 18                 1
# 19                 1
# 20                               1
# 21                 1
# 22                 1
# 23                 1             1
# 24                 1
# 25                 1
# 26                 0
# 27                               1
# 28                 1
# 29                 1
# 30                               1
# 31                 1
# 32                 1             1
# 33                 1
# 34                 1
# 35                 1
# ...

# %%
for col in ['Microsoft/Windows', 'Apple/MacBook']:
    df18.loc[df18[col] == "1", col] = col
df18
# Out:
# 0   Microsoft/Windows  Apple/MacBook Other           nan
# 1                      Apple/MacBook
# 2                      Apple/MacBook
# 3                      Apple/MacBook
# 4   Microsoft/Windows
# 5                                  2
# 6
# 7   Microsoft/Windows
# 8
# 9   Microsoft/Windows
# 10
# 11  Microsoft/Windows
# 12  Microsoft/Windows
# 13                     Apple/MacBook
# 14  Microsoft/Windows
# 15  Microsoft/Windows
# 16  Microsoft/Windows
# 17  Microsoft/Windows  Apple/MacBook
# 18  Microsoft/Windows
# 19  Microsoft/Windows
# 20                     Apple/MacBook
# 21  Microsoft/Windows
# 22  Microsoft/Windows
# 23  Microsoft/Windows  Apple/MacBook
# 24  Microsoft/Windows
# 25  Microsoft/Windows
# 26                  0
# 27                     Apple/MacBook
# 28  Microsoft/Windows
# 29  Microsoft/Windows
# 30                     Apple/MacBook
# 31  Microsoft/Windows
# 32  Microsoft/Windows  Apple/MacBook
# 33  Microsoft/Windows
# 34  Microsoft/Windows
# ...

# %%
df18 = pd.DataFrame(df18.iloc[:,0] + df18.iloc[:,1] + df18.iloc[:,2] + df18.iloc[:,3])
df18
# Out:
#                                  0
# 1                    Apple/MacBook
# 2                    Apple/MacBook
# 3                    Apple/MacBook
# 4                Microsoft/Windows
# 5                                2
# 6
# 7                Microsoft/Windows
# 8
# 9                Microsoft/Windows
# 10
# 11               Microsoft/Windows
# 12               Microsoft/Windows
# 13                   Apple/MacBook
# 14               Microsoft/Windows
# 15               Microsoft/Windows
# 16               Microsoft/Windows
# 17  Microsoft/WindowsApple/MacBook
# 18               Microsoft/Windows
# 19               Microsoft/Windows
# 20                   Apple/MacBook
# 21               Microsoft/Windows
# 22               Microsoft/Windows
# 23  Microsoft/WindowsApple/MacBook
# 24               Microsoft/Windows
# 25               Microsoft/Windows
# 26                               0
# 27                   Apple/MacBook
# 28               Microsoft/Windows
# ...

# %%
df18.columns = ['Q8']
df18
# Out:
#                                 Q8
# 1                    Apple/MacBook
# 2                    Apple/MacBook
# 3                    Apple/MacBook
# 4                Microsoft/Windows
# 5                                2
# 6
# 7                Microsoft/Windows
# 8
# 9                Microsoft/Windows
# 10
# 11               Microsoft/Windows
# 12               Microsoft/Windows
# 13                   Apple/MacBook
# 14               Microsoft/Windows
# 15               Microsoft/Windows
# 16               Microsoft/Windows
# 17  Microsoft/WindowsApple/MacBook
# 18               Microsoft/Windows
# 19               Microsoft/Windows
# 20                   Apple/MacBook
# 21               Microsoft/Windows
# 22               Microsoft/Windows
# 23  Microsoft/WindowsApple/MacBook
# 24               Microsoft/Windows
# 25               Microsoft/Windows
# 26                               0
# 27                   Apple/MacBook
# 28               Microsoft/Windows
# ...

# %%
df19 = pd.concat([df17,df18],axis=1)
df19
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q9

# %%
df20 = df.iloc[:,[27,28,29]]
df20
# Out:
#                 Q9                        Q9.1  \
# 0   Yes, Full Time  Working, but not Full Time
# 1              NaN                         NaN
# 2              NaN                           1
# 3                1                         NaN
# 4              NaN                         NaN
# 5                1                         NaN
# 6              NaN                         NaN
# 7              NaN                           1
# 8              NaN                         NaN
# 9                1                         NaN
# 10             NaN                         NaN
# 11             NaN                         NaN
# 12             NaN                         NaN
# 13             NaN                           1
# 14             NaN                         NaN
# 15             NaN                         NaN
# 16             NaN                         NaN
# 17               1                         NaN
# 18             NaN                         NaN
# ...

# %%
df20.columns = df20.iloc[0].astype(str)
df20 = df20[1:]
df20
# Out:
# 0  Yes, Full Time Working, but not Full Time Not Working while attending Mason
# 1             NaN                        NaN                                 1
# 2             NaN                          1                               NaN
# 3               1                        NaN                               NaN
# 4             NaN                        NaN                                 1
# 5               1                        NaN                               NaN
# 6             NaN                        NaN                               NaN
# 7             NaN                          1                               NaN
# 8             NaN                        NaN                               NaN
# 9               1                        NaN                               NaN
# 10            NaN                        NaN                               NaN
# 11            NaN                        NaN                                 1
# ...

# %%
df20 = df20.fillna('')
df20
# Out:
# 0  Yes, Full Time Working, but not Full Time Not Working while attending Mason
# 1                                                                            1
# 2                                          1
# 3               1
# 4                                                                            1
# 5               1
# 6
# 7                                          1
# 8
# 9               1
# 10
# 11                                                                           1
# 12                                                                           1
# 13                                         1
# 14                                                                           1
# 15                                                                           1
# 16                                                                           1
# 17              1
# 18                                                                           1
# ...

# %%
for col in ['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']:
    df20.loc[df20[col] == "1", col] = col
df20
# Out:
# 0   Yes, Full Time  Working, but not Full Time  \
# 1
# 2                   Working, but not Full Time
# 3   Yes, Full Time
# 4
# 5   Yes, Full Time
# 6
# 7                   Working, but not Full Time
# 8
# 9   Yes, Full Time
# 10
# 11
# 12
# 13                  Working, but not Full Time
# 14
# 15
# 16
# 17  Yes, Full Time
# 18
# 19
# 20                  Working, but not Full Time
# 21  Yes, Full Time
# 22
# 23                  Working, but not Full Time
# 24
# 25  Yes, Full Time
# 26  Yes, Full Time
# 27
# 28
# 29
# 30
# 31  Yes, Full Time
# 32
# 33  Yes, Full Time
# 34  Yes, Full Time
# 35
# 36  Yes, Full Time
#
# 0   Not Working while attending Mason
# 1   Not Working while attending Mason
# 2
# 3
# 4   Not Working while attending Mason
# 5
# 6
# 7
# 8
# 9
# 10
# 11  Not Working while attending Mason
# 12  Not Working while attending Mason
# 13
# 14  Not Working while attending Mason
# 15  Not Working while attending Mason
# 16  Not Working while attending Mason
# 17
# ...

# %%
df20 = pd.DataFrame(df20.iloc[:,0] + df20.iloc[:,1] + df20.iloc[:,2])
df20
# Out:
#                                     0
# 1   Not Working while attending Mason
# 2          Working, but not Full Time
# 3                      Yes, Full Time
# 4   Not Working while attending Mason
# 5                      Yes, Full Time
# 6
# 7          Working, but not Full Time
# 8
# 9                      Yes, Full Time
# 10
# 11  Not Working while attending Mason
# 12  Not Working while attending Mason
# 13         Working, but not Full Time
# 14  Not Working while attending Mason
# 15  Not Working while attending Mason
# 16  Not Working while attending Mason
# 17                     Yes, Full Time
# 18  Not Working while attending Mason
# 19  Not Working while attending Mason
# 20         Working, but not Full Time
# 21                     Yes, Full Time
# 22  Not Working while attending Mason
# 23         Working, but not Full Time
# 24  Not Working while attending Mason
# 25                     Yes, Full Time
# 26                     Yes, Full Time
# ...

# %%
df20.columns = ['Q9']
df20
# Out:
#                                    Q9
# 1   Not Working while attending Mason
# 2          Working, but not Full Time
# 3                      Yes, Full Time
# 4   Not Working while attending Mason
# 5                      Yes, Full Time
# 6
# 7          Working, but not Full Time
# 8
# 9                      Yes, Full Time
# 10
# 11  Not Working while attending Mason
# 12  Not Working while attending Mason
# 13         Working, but not Full Time
# 14  Not Working while attending Mason
# 15  Not Working while attending Mason
# 16  Not Working while attending Mason
# 17                     Yes, Full Time
# 18  Not Working while attending Mason
# 19  Not Working while attending Mason
# 20         Working, but not Full Time
# 21                     Yes, Full Time
# 22  Not Working while attending Mason
# 23         Working, but not Full Time
# 24  Not Working while attending Mason
# 25                     Yes, Full Time
# 26                     Yes, Full Time
# ...

# %%
df21 = pd.concat([df19, df20], axis=1)
df21
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q10

# %%
df22 = df.iloc[:,[30,31,32,33,34]]

df22.columns = df22.iloc[0].astype(str)
df22 = df22[1:]

df22 = df22.fillna('')

for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    df22.loc[df22[col]== "1" , col] = col

df22 = pd.DataFrame(df22.iloc[:,0] + df22.iloc[:,1] + df22.iloc[:,2] + df22.iloc[:,3] + df22.iloc[:,4] )

df22.columns = ['Q10']

df22
# Out:
#                           Q10
# 1            Some familiarity
# 2                Average user
# 3            Some familiarity
# 4                Average user
# 5            Some familiarity
# 6
# 7                Average user
# 8
# 9            Some familiarity
# 10
# 11                Little/none
# 12  Frequent use for projects
# 13           Some familiarity
# 14               Average user
# 15               Average user
# 16           Some familiarity
# 17               Average user
# 18  Frequent use for projects
# 19                Little/none
# 20           Some familiarity
# 21           Some familiarity
# 22           Some familiarity
# 23           Some familiarity
# 24                Little/none
# 25               Average user
# 26               Average user
# 27               Average user
# 28               Average user
# 29               Average user
# 30               Average user
# 31                Little/none
# 32               Average user
# ...

# %%
df23 = pd.concat([df21,df22], axis=1)
df23
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q11

# %%
df24 = df.iloc[:,[35,36,37,38,39]]

df24.columns = df24.iloc[0].astype(str)
df24 = df24[1:]

df24 = df24.fillna('')

for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    df24.loc[df24[col]== "1" , col] = col

df24 = pd.DataFrame(df24.iloc[:,0] + df24.iloc[:,1] + df24.iloc[:,2] + df24.iloc[:,3] + df24.iloc[:,4] )

df24.columns = ['Q11']

df24
# Out:
#                           Q11
# 1                 Little/none
# 2                Average user
# 3                 Little/none
# 4   Frequent use for projects
# 5            Some familiarity
# 6
# 7                Average user
# 8
# 9   Frequent use for projects
# 10
# 11                Little/none
# 12               Average user
# 13               Average user
# 14               Average user
# 15                Little/none
# 16           Some familiarity
# 17           Some familiarity
# 18  Frequent use for projects
# 19                Little/none
# 20              Fluent/expert
# 21           Some familiarity
# 22                Little/none
# 23  Frequent use for projects
# 24                Little/none
# 25               Average user
# 26           Some familiarity
# 27  Frequent use for projects
# 28  Frequent use for projects
# 29               Average user
# 30               Average user
# 31           Some familiarity
# 32  Frequent use for projects
# ...

# %%
df25 = pd.concat([df23,df24], axis=1)
df25
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q12

# %%
df26 = df.iloc[:,[40,41,42,43,44]]

df26.columns = df26.iloc[0].astype(str)
df26 = df26[1:]

df26 = df26.fillna('')

for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    df26.loc[df26[col]== "1" , col] = col

df26 = pd.DataFrame(df26.iloc[:,0] + df26.iloc[:,1] + df26.iloc[:,2] + df26.iloc[:,3] + df26.iloc[:,4] )

df26.columns = ['Q12']

df26
# Out:
#                           Q12
# 1            Some familiarity
# 2                 Little/none
# 3                Average user
# 4            Some familiarity
# 5                Average user
# 6
# 7                Average user
# 8
# 9                Average user
# 10
# 11           Some familiarity
# 12  Frequent use for projects
# 13               Average user
# 14               Average user
# 15                Little/none
# 16           Some familiarity
# 17           Some familiarity
# 18               Average user
# 19               Average user
# 20               Average user
# 21           Some familiarity
# 22               Average user
# 23                Little/none
# 24                Little/none
# 25               Average user
# 26           Some familiarity
# 27               Average user
# 28               Average user
# 29               Average user
# 30  Frequent use for projects
# 31           Some familiarity
# 32  Frequent use for projects
# ...

# %%
df27 = pd.concat([df25,df26], axis=1)
df27
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q13

# %%
df28 = df.iloc[:,[45,46]]

df28.columns = df28.iloc[0].astype(str)
df28 = df28[1:]

df28 = df28.fillna('')

for col in ['Yes', 'No']:
    df28.loc[df28[col] == "1", col] = col

df28 = pd.DataFrame(df28.iloc[:,0] + df28.iloc[:,1])

df28.columns = ['Q13']

df28
# Out:
#     Q13
# 1   Yes
# 2   Yes
# 3    No
# 4    No
# 5    No
# 6   Yes
# 7    No
# 8   Yes
# 9   Yes
# 10   No
# 11   No
# 12   No
# 13   No
# 14   No
# 15   No
# 16   No
# 17   No
# 18   No
# 19   No
# 20   No
# 21   No
# 22   No
# 23  Yes
# 24  Yes
# 25  Yes
# 26   No
# 27   No
# 28  Yes
# 29  Yes
# 30  Yes
# 31  Yes
# 32   No
# 33   No
# 34   No
# 35   No
# 36   No

# %%
df29 = pd.concat([df27, df28], axis=1)
df29
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# ...

# %% [markdown]
# ### Formatting Q14

# %%
df30 = df.iloc[:,[47,48,49]]

df30.columns = df30.iloc[0].astype(str)
df30 = df30[1:]

df30 = df30.fillna('')

for col in ['Yes', 'No', 'Not sure']:
    df30.loc[df30[col] == "1", col] = col

df30 = pd.DataFrame(df30.iloc[:,0] + df30.iloc[:,1] + df30.iloc[:,2])

df30.columns = ['Q14']

df30
# Out:
#          Q14
# 1        Yes
# 2         No
# 3   Not sure
# 4        Yes
# 5        Yes
# 6         No
# 7         No
# 8         No
# 9         No
# 10        No
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19       Yes
# 20  Not sure
# 21  Not sure
# 22  Not sure
# 23  Not sure
# 24  Not sure
# 25  Not sure
# 26  Not sure
# 27       Yes
# 28       Yes
# 29       Yes
# 30       Yes
# 31       Yes
# 32       Yes
# 33        No
# 34        No
# 35  Not sure
# 36  Not sure

# %%
df31 = pd.concat([df29, df30], axis=1)
df31.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# ...

# %% [markdown]
# ### Formatting Q15

# %%
df32 = df.iloc[:,[50]]

df32.columns = df32.iloc[0].astype(str)
df32 = df32[1:]

df32 = df32.fillna('')

df32.columns = ['Q15']

df32.head()
# Out:
#                                                  Q15
# 1
# 2
# 3  As part of my work, I have access to a lot of ...
# 4
# 5                                              Learn

# %%
df33 = pd.concat([df31, df32], axis=1)

df33.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Checking for null values

# %%
df33.isnull().sum()
# Out:
# Time                       0
# Status                     0
# Duration (Seconds)         0
# Access Code               36
# Email Address             36
# IP Address                 0
# Country                    0
# Region                     4
# City / Town / District     5
# Latitude                   0
# Longitude                  0
# Q1                         0
# Q2                         0
# Q3                         0
# Q4                         1
# Q5                         2
# Q6                         2
# Q7                         3
# Q8                         0
# Q9                         0
# Q10                        0
# Q11                        0
# Q12                        0
# Q13                        0
# Q14                        0
# Q15                        0
# dtype: int64

# %%
# Replace NaN values in the access code, email, region, city, Q4, Q5, Q6, Q7

# all values in access code and email address are null so it's better to drop them.
df33 = df33.drop('Access Code', axis=1)
df33 = df33.drop('Email Address', axis=1)

# %%
# can not assume someone's region or city so median, mode etc can not be used here 
df33['Region'] = df33['Region'].fillna('Not Available')
df33['City / Town / District'] = df33['City / Town / District'].fillna('Not Available')

# %%
# changing data type of height then replacing nan values with mean value as height is a numeric value and mean will
# be a good approximation
df33['Q4'] = df33['Q4'].str.replace(' ', '')
df33['Q4'] = pd.to_numeric(df33['Q4'], errors='coerce')
df33['Q4'] = df33['Q4'].fillna(df33['Q4'].mean())

# %%
# using mode for Country of citizenship, undergraduate degree, expected graduation data as as it reflects the most common characteristic in that category
# and  helps maintain the distribution of categories in the dataset.

df33['Q5'] = df33['Q5'].fillna(df33['Q5'].mode()[0])
df33['Q6'] = df33['Q6'].fillna(df33['Q6'].mode()[0])
df33['Q7'] = df33['Q7'].fillna(df33['Q7'].mode()[0])

# %%
# can not use mean, median, mode as this is an open ended question and assumptions can introduce bias or misrepresentation.
df33['Q15'] = df33['Q15'].replace('', 'No Response')
df33.head()
# Out:
#               Time     Status Duration (Seconds)      IP Address  \
# 1  10/3/2023 17:49  Completed              11646  100.36.167.226
# 2  10/3/2023 17:49  Completed                113   98.169.26.134
# 3  10/3/2023 17:49  Completed                572    98.169.52.23
# 4  10/3/2023 17:50  Completed                365  69.255.182.253
# 5  10/3/2023 17:51  Completed                 92  138.88.108.230
#
#          Country         Region City / Town / District  Latitude Longitude  \
# 1  United States       Virginia                Fairfax  -77.2891   38.8209
# 2  United States       Virginia                Fairfax   -77.263   38.8605
# 3  United States       Virginia         Greenway Downs  -77.2331   38.9645
# 4  United States       Virginia            Gainesville  -77.6308   38.8175
# 5  United States  Not Available          Not Available   -97.822    37.751
#
#     Q1  ...                     Q6          Q7                 Q8  \
# ...

# %% [markdown]
# ### Checking for whitespaces

# %%
for col in df33.columns:    
    if df33[col].dtype == 'object':
        df33[col] = df33[col].str.strip()
    else:
        pass

df33.head()
# Out:
#               Time     Status Duration (Seconds)      IP Address  \
# 1  10/3/2023 17:49  Completed              11646  100.36.167.226
# 2  10/3/2023 17:49  Completed                113   98.169.26.134
# 3  10/3/2023 17:49  Completed                572    98.169.52.23
# 4  10/3/2023 17:50  Completed                365  69.255.182.253
# 5  10/3/2023 17:51  Completed                 92  138.88.108.230
#
#          Country         Region City / Town / District  Latitude Longitude  \
# 1  United States       Virginia                Fairfax  -77.2891   38.8209
# 2  United States       Virginia                Fairfax   -77.263   38.8605
# 3  United States       Virginia         Greenway Downs  -77.2331   38.9645
# 4  United States       Virginia            Gainesville  -77.6308   38.8175
# 5  United States  Not Available          Not Available   -97.822    37.751
#
#     Q1  ...                     Q6          Q7                 Q8  \
# ...

# %% [markdown]
# ### Capitalizing the first letter of each word

# %%
for col in df33.columns:    
    if df33[col].dtype == 'object':
        df33[col] = df33[col].str.title()
    else:
        pass

df33.head()
# Out:
#               Time     Status Duration (Seconds)      IP Address  \
# 1  10/3/2023 17:49  Completed              11646  100.36.167.226
# 2  10/3/2023 17:49  Completed                113   98.169.26.134
# 3  10/3/2023 17:49  Completed                572    98.169.52.23
# 4  10/3/2023 17:50  Completed                365  69.255.182.253
# 5  10/3/2023 17:51  Completed                 92  138.88.108.230
#
#          Country         Region City / Town / District  Latitude Longitude  \
# 1  United States       Virginia                Fairfax  -77.2891   38.8209
# 2  United States       Virginia                Fairfax   -77.263   38.8605
# 3  United States       Virginia         Greenway Downs  -77.2331   38.9645
# 4  United States       Virginia            Gainesville  -77.6308   38.8175
# 5  United States  Not Available          Not Available   -97.822    37.751
#
#     Q1  ...                     Q6          Q7                 Q8  \
# ...

# %% [markdown]
# ### Similar undergraduate degress with different names

# %%
idx = df33['Q6'].str.contains('Cs')

df33.loc[idx,'Q6'] = 'Computer Science'

df33.head()
# Out:
#               Time     Status Duration (Seconds)      IP Address  \
# 1  10/3/2023 17:49  Completed              11646  100.36.167.226
# 2  10/3/2023 17:49  Completed                113   98.169.26.134
# 3  10/3/2023 17:49  Completed                572    98.169.52.23
# 4  10/3/2023 17:50  Completed                365  69.255.182.253
# 5  10/3/2023 17:51  Completed                 92  138.88.108.230
#
#          Country         Region City / Town / District  Latitude Longitude  \
# 1  United States       Virginia                Fairfax  -77.2891   38.8209
# 2  United States       Virginia                Fairfax   -77.263   38.8605
# 3  United States       Virginia         Greenway Downs  -77.2331   38.9645
# 4  United States       Virginia            Gainesville  -77.6308   38.8175
# 5  United States  Not Available          Not Available   -97.822    37.751
#
#     Q1  ...                     Q6          Q7                 Q8  \
# ...

# %% [markdown]
# ### Same Country with different names

# %%
idx = df33['Q5'].str.contains('Us')

df33.loc[idx,'Q5'] = 'United States'

df33['Q5']
# Out:
# 1                       Taiwan
# 2                        India
# 3                        India
# 4                  South Korea
# 5                United States
# 6                        India
# 7                     Pakistan
# 8                        India
# 9                        China
# 10                  Uzbekistan
# 11               United States
# 12                       India
# 13                     Romania
# 14                       India
# 15                       China
# 16                  Uzbekistan
# 17               United States
# 18                       India
# 19                    Ethiopia
# 20               United States
# 21               United States
# 22                       India
# 23               United States
# 24                     Nigeria
# 25               United States
# 26                      Taiwan
# 27                       India
# 28                     Nigeria
# 29                       India
# 30                       India
# ...

# %% [markdown]
# ### Changing the data type of columns

# %% [markdown]
# #### Time

# %%
df33['Time'].describe()
# Out:
# count                  36
# unique                 34
# top       10/3/2023 17:49
# freq                    3
# Name: Time, dtype: object

# %%
df33['Time'] = pd.to_datetime(df33['Time']).dt.date
df33['Time'].describe()
# Out:
# count             36
# unique             3
# top       2023-10-03
# freq              15
# Name: Time, dtype: object

# %% [markdown]
# #### Duration

# %%
df33['Duration (Seconds)'].describe()
# Out:
# count        36
# unique       36
# top       11646
# freq          1
# Name: Duration (Seconds), dtype: object

# %%
df33['Duration (Seconds)'] = df33['Duration (Seconds)'].astype(np.int64)
df33['Duration (Seconds)'].describe()
# Out:
# count        36.000000
# mean       7571.027778
# std       28292.029740
# min          40.000000
# 25%         171.500000
# 50%         263.000000
# 75%         537.500000
# max      128253.000000
# Name: Duration (Seconds), dtype: float64

# %% [markdown]
# #### Age

# %%
df33['Q3'].describe()  # age
# Out:
# count     36
# unique    14
# top       23
# freq       7
# Name: Q3, dtype: object

# %%
df33['Q3'] = df33['Q3'].str.replace(' ', '')
df33['Q3'] = df33['Q3'].astype(np.int64)
df33['Q3'].describe()
# Out:
# count      36.000000
# mean       81.666667
# std       327.721310
# min        22.000000
# 25%        23.000000
# 50%        25.000000
# 75%        28.000000
# max      1993.000000
# Name: Q3, dtype: float64

# %% [markdown]
# #### Expected Graduation Date

# %%
df33['Q7'].describe()
# Out:
# count             36
# unique            24
# top       12/20/2021
# freq               6
# Name: Q7, dtype: object

# %%
df['Q7'] = pd.to_datetime(df['Q7'], errors='coerce')
df33['Q7'].describe()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6608\2444614982.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Q7'] = pd.to_datetime(df['Q7'], errors='coerce')
# count             36
# unique            24
# top       12/20/2021
# freq               6
# Name: Q7, dtype: object

# %% [markdown]
# #### Removing outliers

# %% [markdown]
# ##### Age

# %%
Q1 = df33['Q3'].quantile(0.25)
Q3 = df33['Q3'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df33 = df33[(df33['Q3'] >= lower_bound) & (df33['Q3'] <= upper_bound)]

df33['Q3'].describe()
# Out:
# count    32.000000
# mean     25.375000
# std       2.926519
# min      22.000000
# 25%      23.000000
# 50%      25.000000
# 75%      26.250000
# max      35.000000
# Name: Q3, dtype: float64

# %%
df33.to_csv('cleaned_output.csv', index=False)

# %% [markdown]
# ## Part 3

# %%
df33['Q1'].describe()
# Out:
# count      32
# unique      2
# top       2.0
# freq       17
# Name: Q1, dtype: object

# %% [markdown]
# ##### All of the participants answered this question and majority of the participants use 002 AIT-580 Section.

# %%
df33['Q2'].describe()
# Out:
# count         32
# unique         4
# top       Female
# freq          15
# Name: Q2, dtype: object

# %% [markdown]
# ##### Majority of the participants were Females.

# %%
df33['Q3'].describe()
# Out:
# count    32.000000
# mean     25.375000
# std       2.926519
# min      22.000000
# 25%      23.000000
# 50%      25.000000
# 75%      26.250000
# max      35.000000
# Name: Q3, dtype: float64

# %% [markdown]
# ##### Maximum age is 35 and minimum age is 22 and the average age is 25.4. Age data is unavailable for 4 participants.

# %%
df33['Q4'].describe()
# Out:
# count    32.000000
# mean     65.833333
# std      11.647917
# min       5.200000
# 25%      65.933333
# 50%      67.000000
# 75%      70.250000
# max      75.000000
# Name: Q4, dtype: float64

# %% [markdown]
# ##### Mean height is 63.7 and max is 75. Data unavailable for 5 participants.

# %%
df33['Q5'].describe()
# Out:
# count        32
# unique       11
# top       India
# freq         11
# Name: Q5, dtype: object

# %% [markdown]
# ##### Maximum number of the participants are from India

# %%
df33['Q6'].describe()
# Out:
# count            32
# unique           21
# top       Economics
# freq              5
# Name: Q6, dtype: object

# %% [markdown]
# ##### Maximum number of the participants pursued their undergraduate degree in computer science.

# %%
df33['Q7'].describe()
# Out:
# count             32
# unique            22
# top       12/20/2021
# freq               6
# Name: Q7, dtype: object

# %% [markdown]
# ##### There are 23 unique dates among 32 responses which shows considerable variability in the dates

# %%
df33['Q8'].describe()
# Out:
# count                    32
# unique                    7
# top       Microsoft/Windows
# freq                     18
# Name: Q8, dtype: object

# %% [markdown]
# ##### Majority of the participants are Microsoft/Windows users.

# %%
df33['Q9'].describe()
# Out:
# count                                    32
# unique                                    4
# top       Not Working While Attending Mason
# freq                                     17
# Name: Q9, dtype: object

# %% [markdown]
# ##### Majority of the partipants are students and not working.

# %%
df33['Q10'].describe()
# Out:
# count               32
# unique               5
# top       Average User
# freq                13
# Name: Q10, dtype: object

# %% [markdown]
# ##### 13 out of 32 participants have an average skill in Python programming.

# %%
df33['Q11'].describe()
# Out:
# count               32
# unique               6
# top       Average User
# freq                 9
# Name: Q11, dtype: object

# %% [markdown]
# ##### 9 out of 32 participants have an average skill in R programming.

# %%
df33['Q12'].describe()
# Out:
# count               32
# unique               5
# top       Average User
# freq                14
# Name: Q12, dtype: object

# %% [markdown]
# ##### 14 out of 32 participants have an average skill in SQL programming.

# %%
df33['Q13'].describe()
# Out:
# count     32
# unique     2
# top       No
# freq      21
# Name: Q13, dtype: object

# %% [markdown]
# ##### Majority of the participants do not use Github.

# %%
df33['Q14'].describe()
# Out:
# count      32
# unique      3
# top       Yes
# freq       15
# Name: Q14, dtype: object

# %% [markdown]
# ##### Majority of the students are interested in pursuing a career in Data Science/Data Analytics field.

# %%
df33['Q15'].describe()
# Out:
# count              32
# unique             24
# top       No Response
# freq                9
# Name: Q15, dtype: object

# %% [markdown]
# ##### Majority of the students did not repond to this question
